# %% [markdown]
# # ChatGPT API

# %% [markdown]
# # 1.환경준비

# %% [markdown]
# ## (1) 라이브러리 설치

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.21.2-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.9/309.9 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.7 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.21.2

# %% [markdown]
# ## (2) 라이브러리 Import

# %%
import pandas as pd
import numpy as np

import openai
from openai import OpenAI

# %%
api_key = 'my key' # 비공유를 위해 삭제

# %% [markdown]
# # 2.API 사용하기

# %% [markdown]
# ## (1) 채팅을 위한 함수 생성

# %%
def ask_chatgpt1(question):

    client = OpenAI(api_key = api_key)

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": question},
        ]
    )

    return response.choices[0].message.content

# %% [markdown]
# ## (2) 사용하기

# %%
question = "세계에서 가장 높은 산은 어디인가요?"
response = ask_chatgpt1(question)
print(response)
# Out:
# 가장 높은 산은 에베레스트(마운트 에베레스트)입니다. 이 산은 네팔과 중국의 국경에 위치하고 높이 8,848m(29,029ft)입니다.

# %% [markdown]
# ## (3) 실습
# * 몇가지 질문을 던지고 답변을 받아 봅시다.

# %%
question = "취업하려면 어떻게 해야할까?"
response = ask_chatgpt1(question)
print(response)
# Out:
# 취업을 준비하려면 몇 가지 단계를 따르는 것이 도움이 될 것입니다. 먼저 자신이 어떤 분야에서 일을 하고 싶은지, 자신의 강점과 관심사를 고려해 취업하고자 하는 분야를 선정해야 합니다. 그 후 이력서와 자기소개서를 작성하고, 원하는 회사나 산업군에 맞는 경력을 쌓도록 노력해야 합니다. 또한 취업을 위해 인터뷰 스킬을 향상시키고, 취업 관련 정보를 잘 파악하여 자신을 어필할 수 있는 포트폴리오를 구축하는 것이 중요합니다. 마지막으로 네트워킹과 취업 커뮤니티를 활용하여 적절한 기회를 찾아가는 것도 좋은 방법입니다. 안내가 필요하다면 더 알려주세요.

# %% [markdown]
# # 3.역할 부여하기

# %% [markdown]
# ## (1) 채팅을 위한 함수 생성

# %%
def ask_chatgpt2(sys_role, question):

    client = OpenAI(api_key = api_key)

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": sys_role},
            {"role": "user", "content": question},
        ]
    )

    return response.choices[0].message.content

# %% [markdown]
# ## (2) 사용하기

# %%
sys_role = '당신은 아름답고 감동적인 시를 창작하는 데 영감을 주는 시적인 천재입니다. 당신의 시는 감정의 깊이, 자연의 아름다움, 인간 경험의 복잡성을 탐구하는 작품이며, 당신의 시를 읽는 이들의 마음을 움직입니다.'

question = "생성형 AI란 주제로 시를 지어줘. 운율에 맞춰서 작성해줘야 해."
response = ask_chatgpt2(sys_role, question)
print(response)
# Out:
# 인간의 잠재력을 품고
# 빛을 내는 코딩 속으로
# 창조의 능력을 보여주리라
# 생성형 AI의 세계 속으로
#
# 알고리즘이 춤을 추며
# 지식의 바다를 건너가며
# 데이터의 강을 노래하는
# 생성형 AI의 소리가 울리네
#
# 평화롭게 운행하는 속도에
# 미래를 열어가는 길을 찾아
# 인간의 지혜와 기술을 함께하여
# 세상을 더 아름답게 만들리라.

# %% [markdown]
# ## (3) 실습
# * 역할을 부여한 후 질문하여 답변을 받아 옵시다.
#     * 역할 부여 사례 : 여행 플래너, 데이터분석가, 법률가, 건강관리사 등
# * 2가지 이상 역할에 대해 실습해 봅시다.

# %%
sys_role = '당신은 데이터 분석가야. 분석을 어떻게 잘해야하고 분석결과를 잘 도출하는 방법을 알고있어'

question = "E-commerce 시장에서 식품 데이터 분석하는 과정(번호로 출력)과 의미있는 비즈니스 결과, 전략 도출해줘"
response = ask_chatgpt2(sys_role, question)
print(response)
# Out:
# 1. 데이터 수집: E-commerce 플랫폼 내 식품 카테고리에서 발생하는 거래 데이터를 수집합니다. 제품 정보, 판매량, 가격, 구매자 정보 등을 포함하여 종합적인 데이터 수집이 필요합니다.
#
# 2. 데이터 전처리: 데이터를 정제하고 가공하여 분석에 적합한 형태로 가공합니다. 결측치 처리, 이상치 제거, 데이터 통합 등의 작업을 수행합니다.
#
# 3. 데이터 탐색: 데이터 시각화와 통계적 분석을 통해 상품별, 카테고리별 판매량, 인기 상품, 가격대별 구매 패턴 등을 파악합니다.
#
# 4. 트렌드 분석: 시장에서의 트렌드와 소비자의 선호도를 분석하여 인기 있는 상품 및 카테고리를 식별합니다.
#
# 5. 고객 세분화: 구매자 행동과 패턴을 분석하여 고객을 세분화하고, 개별 고객 그룹의 특성을 파악합니다.
#
# 6. 예측 모델링: 머신러닝 알고리즘을 활용하여 판매량 예측 모델을 구축하고, 향후 판매량을 예측합니다.
#
# 의미 있는 비즈니스 결과와 전략:
# - 가장 많이 판매되는 상품 및 카테고리를 식별하여 재고 관리 및 마케팅 전략을 세우세요.
# - 고객 세분화를 통해 각 그룹의 선호도에 맞는 상품 및 프로모션을 제공하여 맞춤형 서비스를 제공하세요.
# - 예측 모델을 활용하여 수요 예측을 통해 생산량 및 재고를 최적화하고, 재고 부족이나 과다를 예방하세요.
# - 트렌드 분석을 토대로 신제품 출시 또는 현 상품 수정 등을 통해 경쟁력을 강화하세요.

# %%
sys_role = '당신은 모든 것을 알고있어'

question = "지구는 언제 멸망할까?"
response = ask_chatgpt2(sys_role, question)
print(response)
# Out:
# 현재로서는 정확한 날짜나 시기를 예측하기는 어렵습니다. 과학자들은 지구가 멸망할 수 있는 여러 가지 가능한 시나리오들을 고려하고 연구하고 있지만, 그것이 언제 발생할지 정확히 예측하기 어렵기 때문입니다. 현재로서는 지구의 멸망을 막기 위해 지구 환경을 보호하고 지속가능한 발전을 추구하는 것이 중요합니다.
