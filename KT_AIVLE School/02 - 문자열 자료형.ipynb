# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/title.png' width=500/></center>

# %% [markdown]
# # 2.문자열 자료형
#
# - 기본 자료형이지만 이해해야 할 부분이 많아 별도로 분리해서 학습합니다.

# %% [markdown]
# ## 2.1.문자열 사용
#
# - Python의 문자열은 많은 편의성과 다양한 기능을 제공합니다.

# %% [markdown]
# **1) 문자열 표현**
#
# - **작은 따옴표**, 또는 **큰 따옴표**를 사용해 문자열을 표현합니다.
# - **len()** 함수로 문자열 길이(=포함된 문자 개수)를 확인할 수 있습니다.

# %%
# 문자열 출력(Hello World)
print('Hello World')
print("Hello World")
# Out:
# Hello World
# Hello World

# %%
# 문자열 변수 선언
a = 'Hello'
b = "World"

# 확인
print(a,b)
# Out:
# Hello World

# %%
# 문자열 길이 확인
print(len(a))
print(len(b))
# Out:
# 5
# 5

# %% [markdown]
# **2) 문자열 나열**
#
# - 문자열을 콤마 없이 나란히 나열하면 합쳐진 결과를 얻습니다.

# %%
# 콤마 없이 나열
s = 'hello' 'world'

# 확인
print(s)
# Out:
# helloworld

# %% [markdown]
# - 문자열을 콤마로 구분하여 나열하면 튜플(Tuple)이 됩니다.
# - 참고로 튜플은 (1, 2, 3) 형태로 소괄호 안에 요소가 나열된 자료형입니다.

# %%
# 콤마로 구분해 나열
s = 'hello', 'world'

# 확인
print(s)
# Out:
# ('hello', 'world')

# %%
a='나이'
b=20
c='살'
print(a,b,c,sep='')
# Out:
# 나이20살

# %%
# print(a+b+c)
print(a+str(b)+c)
# Out:
# 나이20살

# %% [markdown]
# **3) 여러 줄 문자열 표현**
#
# - 문자열 앞뒤에 따옴표 세 개를 나열하거나, \\n을 사용해 여러 줄 표현이 가능합니다.
# - print() 함수를 사용해야 의도한 내용이 제대로 표시됩니다.

# %%
# 여러 줄 문자열 표시
s1 = "여러 줄의 문자열을 표시할 때는 \n을 사용하세요"
s1
# Out:
# '여러 줄의 문자열을 표시할 때는 \n을 사용하세요'

# %%
s1 = "여러 줄의 문자열을 표시할 때는 \n을 사용\n하세요"
print(s1)
# Out:
# 여러 줄의 문자열을 표시할 때는
# 을 사용
# 하세요

# %%
s2 = """또 다른 방법은
큰 따옴표나 작은 따옴표를 세 개 사용하는 것입니다."""
print(s2)
# Out:
# 또 다른 방법은
# 큰 따옴표나 작은 따옴표를 세 개 사용하는 것입니다.

# %% [markdown]
# **4) 문자열에 따옴표 넣기**
#
# - 큰 따옴표 안에 작은 따옴표, 또는 작은 따옴표 안에 큰 따옴표를 사용합니다.
# - \\' 또는 \\\"를 사용해도 됩니다.
# - print() 함수를 사용해야 의도한 내용이 제대로 표시됩니다.

# %%
# 문자열에 따옴표 넣기
s3 = "문자열 안에 따옴표, 예를 들어 '를 넣고 싶을 때는 이렇게 하세요."
print(s3)
# Out:
# 문자열 안에 따옴표, 예를 들어 '를 넣고 싶을 때는 이렇게 하세요.

# %%
s4 = "아니면 \' 또는 \"를 사용해도 됩니다." #★
print(s4)
# Out:
# 아니면 ' 또는 "를 사용해도 됩니다.

# %% [markdown]
# **5) 문자열에 \ 넣기**
#
# - 만일 문자열에 \를 넣고자 한다면 다음 구문과 같이 합니다.

# %%
# 문자열에 \ 넣기
s5 = "아니면 \\' 또는 \\\"를 사용해도 됩니다." #★
print(s5)
# Out:
# 아니면 \' 또는 \"를 사용해도 됩니다.

# %% [markdown]
# ## 2.2.문자열 연산
#
# - 문자열 연산은 숫자 연산과 당연히 다릅니다.
# - 문자열 연산에 대해 알아두면 이후에 편리하게 사용할 수 있습니다.

# %% [markdown]
# **1) 문자열 + 문자열 = 문자열 결합**

# %%
# 문자열 변수
s1 = 'hello'
s2 = 'world'

# 문자열 더하기
hw = s1 + ' ' + s2

# 확인
print(s1+s2)
print(hw)
# Out:
# helloworld
# hello world

# %% [markdown]
# **2) 문자열 * 정수 = 문자열 반복**

# %% [markdown]
#        *****************
#        ** hello world **
#        *****************

# %%
# * 사용해 문자열 반복
print('*****************')
print('**' + ' Hello world **')
print('*'*17)
# Out:
# *****************
# ** Hello world **
# *****************

# %%
# 문자열에 0을 곱하면 문자열이 제거됨
s = 'hello'
print(s * 1)
print(s * 0) # ★
print(s * 2)
print(s * -1000)
# Out:
# hello
#
# hellohello

# %% [markdown]
# ## 2.3.format 메서드 사용
#
# - 문자열 일부분만 바꾸면서 해당 문자열을 재사용할 경우가 있습니다.
# - 예를 들어 문자열에서 이름만 변경하며 사용하는 경우입니다.
# - 이를 **문자열 포맷팅**이라고 하며, **문자열.format()** 형태로 사용합니다.

# %% [markdown]
# **1) 기본 사용법**
#
# - 단순 문자열에서 { }는 아무 의미가 없습니다.

# %%
s='ab c'
print(s.upper())
print(s.split(' '))
# Out:
# AB C
# ['ab', 'c']

# %%
# 단순 문자열
'이름:{}, 과목:{}, 점수:{}'
# Out:
# '이름:{}, 과목:{}, 점수:{}'

# %% [markdown]
# - 하지만 format() 메서드를 만나면 { }는 큰 의미를 가집니다.

# %%
# format 사용
'이름:{}, 과목:{}, 점수:{}'.format('홍길동','국어',90)     # '이름:홍길동, 과목:국어, 점수:90'
# Out:
# '이름:홍길동, 과목:국어, 점수:90'

# %% [markdown]
# - format() 메서드는 대부분 print() 함수 안에서 사용합니다.

# %%
# 변수 선언
fmt = '이름:{}, 연도:{}, 실적:{}'
name = '홍길동'
year = 2019
perf = 2345.6789

# 출력
print(fmt.format(name,year,perf))
print('이름:{}, 연도:{}, 실적:{}'.format(name,year,perf))
# Out:
# 이름:홍길동, 연도:2019, 실적:2345.6789
# 이름:홍길동, 연도:2019, 실적:2345.6789

# %% [markdown]
# **2) 표시 위치 지정**
#
# - { } 안에 변수 위치 값을 지정해야 하지만, 순서대로 사용될 것이면 생략하는 경우가 많습니다.
# - { } 는 출력되는 값 순서 외에도 출력되는 형태, 즉 자리수 등을 제어할 수 있는 기능도 있습니다.

# %%
# 변수 선언
name = '홍길동'
year = 2019
perf = 2345.6789

# 출력
print('이름:{0}, 연도:{1}, 실적:{2}'.format(name,year,perf)          )
print('이름:{0}, 연도:{1}, 실적:{2:.2f}'.format(name,year,perf)      )  
print('이름:{}, 연도:{}, 실적:{:,.2f}'.format(name,year,perf)         ) # 천단위 찍기 #★
print('이름:{}, 연도:{}, 실적:{:15,.2f}'.format(name,year,perf)         ) # 15 전체단위수

print()
print('실적:{2}, 연도:{1}, 이름:{0:,.2f}'.format(perf, year, name)         )
# Out:
# 이름:홍길동, 연도:2019, 실적:2345.6789
# 이름:홍길동, 연도:2019, 실적:2345.68
# 이름:홍길동, 연도:2019, 실적:2,345.68
# 이름:홍길동, 연도:2019, 실적:       2,345.68
#
# 실적:홍길동, 연도:2019, 이름:2,345.68

# %% [markdown]
# **3) 자릿수와 정렬 방식 지정**
#
# - 좀 더 세밀한 출력 형태를 지정하고 싶은 경우 사용합니다.

# %%
# 소수점 자리수 제한
print('{:.5f}'.format(12.123456))
# Out:
# 12.12346

# %%
print('{:20.5f}'.format(12.123456)) # 20은 자리수
# Out:
#             12.12346

# %%
# 위치만 지정
print('[{0}] [{1}]'.format('홍길동', 1200))
# Out:
# [홍길동] [1200]

# %%
# 기본 정렬
print('[{0:10}] [{1:6}]'.format('홍길동', 1200)) # 10은 자리수 #★
# Out:
# [홍길동       ] [  1200]

# %%
print('[{0:10}] [{1:6,}]'.format('홍길동', 1200)) # , 천단위표시 / 문자 왼쪽정렬, 숫자 오른쪽정렬
# Out:
# [홍길동       ] [ 1,200]

# %%
print('[{0:10}] [{1:10,.2f}]'.format('홍길동', 1200)) # 10 자리수 / .2f 소수점자리수
# Out:
# [홍길동       ] [  1,200.00]

# %%
# 오른쪽, 왼쪽 정렬
print('[{0:>10}] [{1:<6}]'.format('홍길동', 1200)) # > 오른쪽 정렬 #★
# Out:
# [       홍길동] [1200  ]

# %%
# 가운데 정렬
print('[{0:^10}] [{1:^6}]'.format('홍길동', 1200)) # 가운데 정렬 #★
# Out:
# [   홍길동    ] [ 1200 ]

# %%
print('[{0:^10}] [{1:^6}]'.format('홍길동', 1200))
# Out:
# [   홍길동    ] [ 1200 ]

# %%
# 공백을 다른 문자로 채우기
print('[{0:-^10}] [{1:_^6}]'.format('홍길동', 1200)) # 공백채우기  #★
# Out:
# [---홍길동----] [_1200_]

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] 자신의 이름과 학창시절 국어, 수학, 영어 점수를 각 변수에 대입하세요.

# %%
# 변수 선언
name ='박'
kor =10
math =10
eng =100

# %% [markdown]
# [문2] 세 과목의 합을 구해 보세요.

# %%
# 합 구하기
my_sum =kor+math+eng
my_sum

# %% [markdown]
# [문3] 세 과목의 평균을 구해 보세요.

# %%
# 평균 구하기
my_mean = my_sum / 3
my_mean
# Out:
# 40.0

# %% [markdown]
# [문4] 다음 코드의 잘못 된 부분을 수정해서 결과가 제대로 표시되게 하세요.

# %%
# 수정 전
# print('{} 학생의 점수 합은 {} 이고 평균은 {:.2f} 입니다.'.format(Name, Mean, Sum))

# %%
# 수정 후
print('{} 학생의 점수 합은 {} 이고 평균은 {:.2f} 입니다.'.format(name, my_sum, my_mean))
# Out:
# 박 학생의 점수 합은 120 이고 평균은 40.00 입니다.

# %%
print('{0} 학생의 점수 합은 {1} 이고 평균은 {2:.2f} 입니다.'.format(name, my_sum, my_mean))
# Out:
# 박 학생의 점수 합은 120 이고 평균은 40.00 입니다.

# %% [markdown]
# ## 2.4.f-String
#
# - 최근에는 다음과 같은 방법(f-String)을 많이 사용합니다.

# %%
# 반복=format 형식, 한번 f string이 좋음 #★

# %%
# 변수 선언
name = '홍길동'
age = 25
score = 2345.6789

# 확인
print(f'이름: {name}') #★
print(f'나이: {age}')
print(f'점수: {score}')
print(f'{age}살의 {name}의 점수는 {score}입니다.')
# Out:
# 이름: 홍길동
# 나이: 25
# 점수: 2345.6789
# 25살의 홍길동의 점수는 2345.6789입니다.

# %% [markdown]
# - 출력되는 형태를 나름으로 조절할 수 있습니다. (참고: 문자열:s, 정수:d, 실수:f)

# %%
# 확인
print(f'{age}살의 {name}의 점수는 {score:,.2f}입니다.') #★
# Out:
# 25살의 홍길동의 점수는 2,345.68입니다.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] 우선 다음 코드를 실행하여 점수 합계와 평균을 구하세요.

# %%
# 변수 선언
name = '홍길동'
age = 25
score1 = 153
score2 = 204
score3 = 259
score4 = 221
score5 = 267

# 합계
tot_score = score1 + score2 + score3 + score4 + score5

# 평균
avg_score = tot_score / 5

# 연령대
age_group = age // 10 * 10

# %%
# Out:
# 20

# %% [markdown]
# [문2]  f-String을 사용해 위 변수들 값이 다음과 같은 형태로 출력되도록 코드를 작성하세요.
#
# ~~~
# 이름: 홍길동
# 연령대: 20대
# 점수: 153, 204, 259, 221, 267
# 합계: 1,104 / 평균: 220.80
# ~~~

# %%
# 확인
print(f'이름: {name}')
print(f'연령대: {age_group}')
print(f'점수: {score1}, {score2}, {score3}, {score4}, {score5}')
print(f'합계: {tot_score:,} / 평균: {avg_score:.2f}')
# Out:
# 이름: 홍길동
# 연령대: 20
# 점수: 153, 204, 259, 221, 267
# 합계: 1,104 / 평균: 220.80

# %%
print(f'합계: {tot_score:,}\n평균: {avg_score:.2f}') #★
# Out:
# 합계: 1,104
# 평균: 220.80

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## 2.5.문자열 인덱싱과 슬라이싱
#
# - 문자열은 문자 요소가 모여서 만들어진 자료형, 즉 **'ABC'는 'A', 'B', 'C' 세 요소가 모인 것**입니다.
# - 정수형 위치 인덱스를 사용해 원하는 요소를 조회하는 것을 **인덱싱(Indexing)** 이라고 합니다.
# - 범위를 지정해 일정 범위의 요소를 조회하는 것을 **슬라이싱(Slicing)** 이라고 합니다.
# - <font color="red">인덱스 값은 0부터 시작</font>함을 잊어서는 안됩니다.
# - 문자열 인덱싱과 슬라이싱은 이후에 다룰 리스트(List)와 비슷한 특성을 가집니다.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/zero.png' width=560 align="left"/>

# %% [markdown]
# **1) 문자열 인덱싱**
#
# <img src='https://raw.githubusercontent.com/jangrae/img/master/str_indexing.png' width=560 align="left"/>

# %%
# 문자열 변수
s = '나의살던고향은꽃피는산골'

# 문자열 인덱싱 #★
print(s[4])
print(s[-8])
print(s[-5])
print(s[-1])
# Out:
# 고
# 고
# 꽃
# 골

# %% [markdown]
# **2) 문자열 슬라이싱**
#
# <img src='https://raw.githubusercontent.com/jangrae/img/master/str_slicing.png' width=450 align="left"/>

# %%
# 문자열 변수
s = '나의살던고향은꽃피는산골'

# 문자열 슬라이싱  #★
print(s[4:6]) 
print(s[0:5]) 
print(s[:5]) 
print(s[4:])
print(s[-2:])
print(s[10:])
# Out:
# 고향
# 나의살던고
# 나의살던고
# 고향은꽃피는산골
# 산골
# 산골

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align='left'/>

# %% [markdown]
# [문1] 다음 셀의 결과를 확인한 후 이어지는 셀을 완성해 보세요.

# %%
my_str = 'Let\'s learn Python.'
print(my_str)                      # Let's learn Python.
# Out:
# Let's learn Python.

# %%
# 다음 코드 실행 결과를 예측 해보기
print(my_str[6])                   # 인덱싱할때 \는 글자수로 포함되지 않는다 #★
print(my_str[10])                  # 
print(my_str[6:11])                #
# Out:
# l
# n
# learn

# %%
# Python 문자열이 표시되게 하려면?
print(my_str[12:18])                   # Python
# Out:
# Python

# %% [markdown]
# **[참고] 인덱싱으로 문자열 변경 불가**
#
# - 인덱싱, 슬라이싱을 사용해 문자를 변경할 수는 없습니다.

# %%
# 문자 변경 불가 #★
s = '나의살던고향은꽃피는산골'

# s[0] = '너'                        
# TypeError: 'str' object does not support item assignment
# 다시 선언해야함,초기화 / s='너의살던고향은꽃피는산골'

# %%
a=10
b=a
print(id(a))
print(id(b))
print(a is b)
print()

a=a+1
print(id(a))
print()

a=a-1
print(id(a))
# Out:
# 1235507833424
# 1235507833424
# True
#
# 1235507833456
#
# 1235507833424

# %% [markdown]
# ## 2.6.문자열 관련 주요 메서드
#
# * 변수(또는 개체) 뒤에 '.함수' 형태로 사용하는 함수를 **메서드(Method)** 라고 부릅니다.
# - 아래 언급된 메서드 외에도 문자열 관련 메서드가 상당히 많으니 관련 자료를 참고하기 바랍니다.
# - 문자열을 변환하는 메서드를 사용해도 그 결과가 변수에 반영되지는 않습니다.

# %%
# 대문자로 변환
s = 'I have a Dream.'
print(s.upper())         # I HAVE A DREAM.
print(s)                 # I have a Dream.
# Out:
# I HAVE A DREAM.
# I have a Dream.

# %% [markdown]
# - 변환 결과를 변수에 반영하려면 메서드가 반환하는 값을 변수에 대입해야 합니다.

# %%
# 대문자로 변환
s = 'I have a Dream.'
print(s.upper())         # I HAVE A DREAM.

# 변수에 반영
s = s.upper()
print(s)                 # I HAVE A DREAM.
# Out:
# I HAVE A DREAM.
# I HAVE A DREAM.

# %% [markdown]
# **1) 대/소문자 변환**
#
# - **capitalize()** 메서드: 문자열 첫 문자만 대문자, 나머지 모두 소문자로 변환합니다.
# - **title()** 메서드: 단어 첫 문자만 대문자, 나머지는 모두 소문자로 변환합니다.
# - **upper()** 메서드: 모든 문자를 대문자로 변환합니다.
# - **lower()** 메서드: 모든 문자를 소문자로 변환합니다.

# %%
# 대/소문자 변환
s = 'I have a Dream. I have a power'
print(s.capitalize()) # 첫글자 대문자, 나머지 소문자!
print(s.title())
print(s.upper())
print(s.lower())

s
# Out:
# I have a dream. i have a power
# I Have A Dream. I Have A Power
# I HAVE A DREAM. I HAVE A POWER
# i have a dream. i have a power
# 'I have a Dream. I have a power'

# %%
print(s[:6].title())
# Out:
# I Have

# %% [markdown]
# **2) 자릿수 지정과 정렬**
#
# - **rjust(x)** 메서드: 지정한 x 만큼의 자릿수를 확보한 후 오른쪽 정렬합니다.
# - **ljust(x)** 메서드: 지정한 x 만큼의 자릿수를 확보한 후 왼쪽 정렬합니다.
# - **center(x)** 메서드: 지정한 x 만큼의 자릿수를 확보한 후 가운데 정렬합니다.

# %%
# 지정한 길이의 문자열이 되도록 공백을 추가하고 정렬
s = 'Dream'
print('[' + s.rjust(7) + ']') # 7자리 만들고, 오른쪽정렬 #★잘안쓰긴함
print('[' + s.ljust(7) + ']')
print('[' + s.center(7) + ']')
# Out:
# [  Dream]
# [Dream  ]
# [ Dream ]

# %% [markdown]
# **3) 일부 변경 및 제거**
#
# - **replace(x, y)** 메서드: 문자열에 포함된 일부 문자열 x를 문자열 y로 변경합니다.
# - **strip(x)** 메서드: 문자열에서 양쪽의 공백 또는 특수 문자를 제거합니다.

# %%
# 문자열 변경('now' --> 'now ')
s = 'nowhere'
print(s.replace('now', 'now ')) #★
print(s)
# Out:
# now here
# nowhere

# %%
# 맨앞/뒤 공백, 특수 문자 제거
print('  world '.strip()) #★
print('#world#$$#'.strip())
print(' #world#$$#'.strip('$# ')) # 맨 앞/뒤에 $, # 삭제
print(' $world#$$#'.strip('$# ')) 
print(' #world#$$#💕'.strip('$#💕 '))
# Out:
# world
# #world#$$#
# world
# world
# world

# %% [markdown]
# - replace() 메서드를 사용하는 경우가 많으니 꼭 기억합니다.

# %%
# 문자열 변수
num = '123,456'
print('1: ', num * 2) # int 아니어서 문자로 연산

# 콤마 제거 후 정수로 변환
num=int(num.replace(',','')) # 동일 1) +2)
# 1) num=num.replace(',','') 
# 2) num = int(num)

# 연산
print('2: ', num * 2)
# Out:
# 1:  123,456123,456
# 2:  246912

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] 다음 코드의 실행 결과가 '파이썬을 열심히 공부할께요!'가 되게 수정해 보세요.

# %%
# 문자열 변수 선언
my_str = '파이썬을 대충 공부할께요!'

# 문자열 변환
my_str.replace('대충','열심히')
# Out:
# '파이썬을 열심히 공부할께요!'

# %%
my_str
# Out:
# '파이썬을 대충 공부할께요!'

# %% [markdown]
# **4) 분리와 연결** #★
#
# - **split((x)** 메서드: x문자를 구분자로 하여 문자열을 분리하여 리스트로 변환합니다.(공백이 기본 구분자xx)
# - **x.join(s)** 메서드: x를 구분자로 하여 요소들을 연결한 문자열로 변환합니다.

# %%
# 문자열 변수
s = 'I have a Dream!'

# 문자열 분리
print(s.split())
# Out:
# ['I', 'have', 'a', 'Dream!']

# %%
# 문자열 변수
s = 'I hav\te a Dr\neam!' 

# 문자열 분리
print(s.split()) # 화이트캐릭터(\t, \n 등) 기준, 공백기준 구분 아님 #★
print(s.split(' ')) # 공백이 구분자
# Out:
# ['I', 'hav', 'e', 'a', 'Dr', 'eam!']
# ['I', 'hav\te', 'a', 'Dr\neam!']

# %%
# 문자열 변수
s = '2020-09-14'

# 문자열 분리
print(s.split('-'))
print(s.split('-')[0])
# Out:
# ['2020', '09', '14']
# 2020

# %%
# 문자열 변수
s = '1/2/3/4/5/6/7/8/9'

# 문자열 분리
s_new = s.split('/')

# 확인
print(s_new)
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
# 문자열 변수
s = '2020-09-14'

# 문자열 분리
year = s.split('-')[0]
month = s.split('-')[1]
day = s.split('-')[2]

# 확인
print('오늘은', year + '년', month + '월', day + '일 입니다.')
# Out:
# 오늘은 2020년 09월 14일 입니다.

# %% [markdown]
# - 위 구문을 다른 방법으로 작성할 수 있습니다.
# - 위 구문과 아래 구문의 차이를 생각해 보세요.

# %%
# 문자열 변수
s = '2020-09-14'

# 문자열 분리
dt = s.split('-')

# 확인
print('오늘은', dt[0], '년', dt[1], '월', dt[2], '일 입니다.')
# Out:
# 오늘은 2020 년 09 월 14 일 입니다.

# %%
# 문자열 변수
s = '2020-09-14'

# 확인
print('오늘은', s.split('-')[0] , '년', s.split('-')[1] , '월', s.split('-')[2] , '일 입니다.')
# Out:
# 오늘은 2020 년 09 월 14 일 입니다.

# %% [markdown]
# - join() 메서드로 구분자를 두어 연결된 문자열을 만듭니다.

# %%
# 중간에 특정 문자열 삽입 # 원하는 구분자로 연결 / split 반대개념 #★ 
s = 'PYTHON'
s1 = '/'
print(s1.join(s))
print('/'.join(s))
# Out:
# P/Y/T/H/O/N
# P/Y/T/H/O/N

# %%
# 요소를 연결해서 문자열로
a = ['홍길동', '한사랑', '강우동', '박여인']
s =' / '.join(a)

# 확인
s
# Out:
# '홍길동 / 한사랑 / 강우동 / 박여인'

# %%
# 문자열 s를 구분자로 나누어 리스트로
b =s.split(' / ')

# 확인
b
# Out:
# ['홍길동', '한사랑', '강우동', '박여인']

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] 다음 주어진 문자열을 적절한 구분자를 기준으로 분리하세요.

# %%
# 문자열 변수
my_str = '15, 23, 52, 41, 25, 60, 47, 28, 49, 60'

# 문자열 분리
my_str.split(', ')
# Out:
# ['15', '23', '52', '41', '25', '60', '47', '28', '49', '60']

# %% [markdown]
# [문2] 다음 주어진 리스트의 요소를 yyyy-mm-dd 형태로 연결해 dt 변수에 담고 결과를  확인하세요.

# %%
# 리스트 만들기
my_list = ['2020', '09', '14']

# 문자열 연결
dt ='-'.join(my_list)

# 확인
dt
# Out:
# '2020-09-14'

# %% [markdown]
# [문3] 위에서 배운 문자열 관련 메서드를 사용해 다음 주어진 리스트의 요소를 모두 대문자로 바꾸세요.

# %%
# 리스트 만들기
a = ['h', 'a', 'p',  'p', 'y']

# 대문자로 변경
a = ','.join(a).upper().split(',')

# 확인
a
# Out:
# ['H', 'A', 'P', 'P', 'Y']

# %% [markdown]
# **5) 표시 형식 지정**
#
# - **format()** 메서드는 데이터 표시 위치와 모양을 설정할 때 사용합니다.

# %%
# 변수 선언
a, b, c = 10, 'Hello', 0.1

# 확인
print('{} {} {}'.format(a, b, c))
# Out:
# 10 Hello 0.1
