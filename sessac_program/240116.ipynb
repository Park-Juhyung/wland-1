# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 시작

# %%
# pip install pyopenssl
# pip install request
# pip install bs4

# %%
https://www.data.go.kr/data/15059093/openapi.do

# %%
html_doc=
'''
<html><head><title>TheDormouse'sstory</title></head> 
    <body> <pclass="title"><b>TheDormouse's story</b></p> 
        <pclass="story">Onceuponatimetherewerethreelittlesisters;andtheirnames ˓→were 

<item>
    <ahref="http://example.com/elsie"class="sister"id="link1">Elsie</a>, 
</item>
<item>
    <ahref="http://example.com/lacie"class="sister"id="link2">Lacie</a>and 
</item>
<item>
    <ahref="http://example.com/tillie"class="sister"id="link3">Tillie</a>; 
    andtheylivedatthebottomofawell.</p> 
</item>
<pclass="story">...</p> 
'''
# Out:
#   File "C:\Users\jh\AppData\Local\Temp\ipykernel_19016\395542677.py", line 1
#     html_doc=
#              ^
# SyntaxError: invalid syntax

# %%
from bs4 import BeautifulSoup 
soup=BeautifulSoup(html_doc,'html.parser') 
print(soup.prettify()) #<html> # <head> # <title> # TheDormouse'sstory # </title> # </head> # <body> # <pclass="title"> # <b>
# Out:
# <html>
#  <head>
#   <title>
#    TheDormouse'sstory
#   </title>
#  </head>
#  <body>
#   <pclass="title">
#    <b>
#     TheDormouse's story
#    </b>
#    <pclass="story">
#     Onceuponatimetherewerethreelittlesisters;andtheirnames ˓→were
#     <ahref="http: elsie"class="sister" example.com="" id="link1">
#      Elsie
#      ,
#      <ahref="http: example.com="" id="link2" lacie"class="sister">
#       Lacie
#       and
#       <ahref="http: example.com="" id="link3" tillie"class="sister">
#        Tillie
#        ; andtheylivedatthebottomofawell.
#        <pclass="story">
#         ...
#        </pclass="story">
#       </ahref="http:>
#      </ahref="http:>
#     </ahref="http:>
#    </pclass="story">
#   </pclass="title">
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>TheDormouse'sstory</title>

# %%
soup.a

# %%
soup.find_all('a')
# Out:
# []

# %%
soup.a.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19016\3706355426.py in <module>
# ----> 1 soup.a.text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for x in soup.find_all('a'):
    print(x.text)

# %%
soup=BeautifulSoup(html_doc,'html.parser')
soup
# Out:
#  <html><head><title>TheDormouse'sstory</title></head> <body> <pclass="title"><b>TheDormouse's story</b> <pclass="story">Onceuponatimetherewerethreelittlesisters;andtheirnames ˓→were <ahref="http: elsie"class="sister" example.com="" id="link1">Elsie, <ahref="http: example.com="" id="link2" lacie"class="sister">Lacieand <ahref="http: example.com="" id="link3" tillie"class="sister">Tillie; andtheylivedatthebottomofawell. <pclass="story">... </pclass="story"></ahref="http:></ahref="http:></ahref="http:></pclass="story"></pclass="title"></body></html>

# %%
soup.point

# %%
for x in soup.find_all('point'):
    print(x.text)

# %%
# Out:
# []

# %%
for item in soup.find_all('item'):
    print('-'*100)
    print(item)

# %%
for item in soup.find_all('item'):
    print('-'*100)
    print(item.a.text)
    print(item.point.text)

# %%
alist=[]
pointlist=[]
for item in soup.find_all('item'):
    print('-'*100)
    a=item.a.text
    point=item.point.text
    alist.append(a)
    pointlist.append(point)

import pandas as pd
df=pd.DataFrame({'이름':alist,
      '포인트':pointlist
      })
df
# Out:
# Empty DataFrame
# Columns: [이름, 포인트]
# Index: []

# %% [markdown]
# # API

# %%
urlbase='https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey='
key='ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D'
urlelse='&pageNo=1&numOfRows=10&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt='
startdate='20100101'
url2='&endDt='
enddate='20100601'
url3='&stnIds='
city='108'

url=urlbase+key+urlelse+startdate+url2+enddate+url3+city
url
# Out:
# 'https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D&pageNo=1&numOfRows=10&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20100101&endDt=20100601&stnIds=108'

# %%
url='https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey='
key='ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D
&pageNo=1&numOfRows=10&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20100101&endDt=20100601&stnIds=108'

# %%
import requests
from urllib.request import urlopen
from urllib import parse

url=urlopen(url)
url

# %% [markdown]
# # 홈페이지

# %%
url='https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D&pageNo=1&numOfRows=10&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20100101&endDt=20100601&stnIds=108'

url
# Out:
# 'https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D&pageNo=1&numOfRows=10&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20100101&endDt=20100601&stnIds=108'

# %%
# 교수님
# urlBase='https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey='
# key='Y9vZZYdTITnGhBz7r3628UaVagdVfFEt7urjSsx3ha5rmD9ohXbuD546nfVlktbIbE9G5At1lXbcXKSo%2BEYYig%3D%3D'
# urlElse='&pageNo=1&numOfRows=10&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20100101&endDt=20100601&stnIds=108'
# url=urlBase+key+urlElse
# url

# %%
# #홈피방법
# import requests

# url = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList'
# params ={'serviceKey' : 'ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D', 'pageNo' : '1', 'numOfRows' : '10', 'dataType' : 'XML', 'dataCd' : 'ASOS', 'dateCd' : 'DAY', 'startDt' : '20100101', 'endDt' : '20100601', 'stnIds' : '108' }

# response = requests.get(url, params=params)
# print(response.content)

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

xml=requests.get(url)
soup=bs(xml.text, 'html.parser')

soup.find_all('item')
# Out:
# c:\Users\jh\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# ...

# %%
for item in soup.find_all('item'):
    print(item)
# Out:
# <item><stnid>108</stnid><stnnm>서울</stnnm><tm>2010-01-01</tm><avgta>-7.6</avgta><minta>-12.7</minta><mintahrmt>0654</mintahrmt><maxta>-3.6</maxta><maxtahrmt>1501</maxtahrmt><mi10maxrn></mi10maxrn><mi10maxrnhrmt></mi10maxrnhrmt><hr1maxrn></hr1maxrn><hr1maxrnhrmt></hr1maxrnhrmt><sumrndur></sumrndur><sumrn></sumrn><maxinsws>7.5</maxinsws><maxinswswd>340</maxinswswd><maxinswshrmt>0105</maxinswshrmt><maxws>3.4</maxws><maxwswd>70</maxwswd><maxwshrmt>2350</maxwshrmt><avgws>1.9</avgws><hr24sumrws>1608</hr24sumrws><maxwd>70</maxwd><avgtd>-16.9</avgtd><minrhm>30</minrhm><minrhmhrmt>1137</minrhmhrmt><avgrhm>48.0</avgrhm><avgpv>1.7</avgpv><avgpa>1010.6</avgpa><maxps>1024.4</maxps><maxpshrmt>0005</maxpshrmt><minps>1019.4</minps><minpshrmt>2356</minpshrmt><avgps>1021.7</avgps><ssdur>9.6</ssdur><sumsshr>7.3</sumsshr><hr1maxicsrhrmt>1100</hr1maxicsrhrmt><hr1maxicsr>1.51</hr1maxicsr><sumgsr>8.63</sumgsr><ddmefs></ddmefs><ddmefshrmt></ddmefshrmt><ddmes>2.2</ddmes><ddmeshrmt>0000</ddmeshrmt><sumdpthfhsc
# ...

# %%
citylist,mintalist,maxtalist,datelist=[],[],[],[]

for item in soup.find_all('item'):
    citylist=item.stnnm.text
    mintalist.append(item.minta.text)
    maxtalist.append(item.maxta.text)
    datelist.append(item.tm.text)

df=pd.DataFrame({'city':citylist,
                 '날짜':datelist,
              '최저':mintalist,
              '최고기온':maxtalist})
df
# Out:
#   city          날짜     최저  최고기온
# 0   서울  2010-01-01  -12.7  -3.6
# 1   서울  2010-01-02   -7.4   0.2
# 2   서울  2010-01-03  -10.5  -3.2
# 3   서울  2010-01-04   -8.0  -3.4
# 4   서울  2010-01-05  -12.3  -7.0
# 5   서울  2010-01-06  -13.3  -8.1
# 6   서울  2010-01-07  -13.6  -5.5
# 7   서울  2010-01-08  -11.8  -3.3
# 8   서울  2010-01-09   -8.7  -1.9
# 9   서울  2010-01-10   -5.3  -0.3

# %% [markdown]
# # 증권 데이터 API 실습

# %%
import requests

url = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList'
params ={'serviceKey' : 'ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D', 'pageNo' : '1', 'numOfRows' : '10', 'dataType' : 'XML', 'dataCd' : 'ASOS', 'dateCd' : 'DAY', 'startDt' : '20100101', 'endDt' : '20100601', 'stnIds' : '108' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
response.text
# Out:
# '<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
import requests
import pprint
import json

# %%
url='https://apis.data.go.kr/B190017/service/GetInsuredProductService202008/getProductList202008?serviceKey=ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D&pageNo=1&numOfRows=10&resultType=xml&regnNm=%EA%B8%88%EC%9C%B5%ED%88%AC%EC%9E%90&fncIstNm=SK%EC%A6%9D%EA%B6%8C%EC%A3%BC%EC%8B%9D%ED%9A%8C%EC%82%AC&prdNm=%EB%B9%84%EA%B3%BC%EC%84%B8%EC%9E%A5%EA%B8%B0%ED%9A%8C%EC%82%AC%EC%B1%84%ED%98%95'

# %%
import requests

url = 'http://apis.data.go.kr/B190017/service/GetInsuredProductService202008'
params ={'serviceKey' : 'ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D', 'pageNo' : '1', 'numOfRows' : '10', 'dataType' : 'XML', 'dataCd' : 'ASOS', 'dateCd' : 'DAY', 'startDt' : '20100101', 'endDt' : '20100601', 'stnIds' : '108' }

response = requests.get(url, params=params)
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">
#     <soapenv:Body>
#         <soapenv:Fault>
#             <faultcode>soapenv:Server</faultcode>
#             <faultstring>Policy Falsified</faultstring>
#             <faultactor>http://apis.data.go.kr/B190017/service/GetInsuredProductService202008?serviceKey=ymBVj390b45Rr2hErpFD98uFKeYo77slk%252BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%253D%253D&amp;pageNo=1&amp;numOfRows=10&amp;dataType=XML&amp;dataCd=ASOS&amp;dateCd=DAY&amp;startDt=20100101&amp;endDt=20100601&amp;stnIds=108</faultactor>
#             <detail>
#                 <l7:policyResult
#                     status="Service Not Found.  The request may have been sent to an invalid URL, or intended for an unsupported operation." xmlns:l7="http://www.layer7tech.com/ws/policy/fault"/>
#             </detail>
#         </soapenv:Fault>
#     </soapenv:Body>
# </soapenv:Envelope>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">\n    <soapenv:Body>\n        <soapenv:Fault>\n            <faultcode>soapenv:Server</faultcode>\n            <faultstring>Policy Falsified</faultstring>\n            <faultactor>http://apis.data.go.kr/B190017/service/GetInsuredProductService202008?serviceKey=ymBVj390b45Rr2hErpFD98uFKeYo77slk%252BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%253D%253D&amp;pageNo=1&amp;numOfRows=10&amp;dataType=XML&amp;dataCd=ASOS&amp;dateCd=DAY&amp;startDt=20100101&amp;endDt=20100601&amp;stnIds=108</faultactor>\n            <detail>\n                <l7:policyResult\n                    status="Service Not Found.  The request may have been sent to an invalid URL, or intended for an unsupported operation." xmlns:l7="http://www.layer7tech.com/ws/policy/fault"/>\n            </detail>\n        </soapenv:Fault>\n    </soapenv:Body>\n</soapenv:Envelope>\n'

# %%
from urllib.request import urlopen  #1
from bs4 import BeautifulSoup  #2


result = urlopen(url)  #7
house = BeautifulSoup(result, 'lxml-xml')  #8
te = house.find_all('item')  #9
te
# Out:
# []

# %%
import requests

url = 'http://apis.data.go.kr/B190017/service/GetInsuredProductService202008/getProductList202008'
params ={'serviceKey' : 'ymBVj390b45Rr2hErpFD98uFKeYo77slk+RJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g==', 'pageNo' : '1', 'numOfRows' : '10', 'resultType' : 'xml', 'regnNm' : '금융투자', 'fncIstNm' : 'SK증권주식회사', 'prdNm' : '비과세장기회사채형' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<response>\n  <header>\n    <resultCode>00</resultCode>\n    <resultMsg>NORMAL SERVICE</resultMsg>\n  </header>\n  <body>\n    <items/>\n    <numOfRows>10</numOfRows>\n    <pageNo>1</pageNo>\n    <totalCount>0</totalCount>\n  </body>\n</response>\n'

# %%
import requests

url = 'http://apis.data.go.kr/B190017/service/GetInsuredProductService202008/getProductList202008'
params = {
    'serviceKey': 'ymBVj390b45Rr2hErpFD98uFKeYo77slk+RJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g==',
    'pageNo': '1',
    'numOfRows': '10',
    'resultType': 'xml',
    'regnNm': '금융투자',
    'fncIstNm': 'SK증권주식회사',
    'prdNm': '비과세장기회사채형'
}

response = requests.get(url, params=params)

print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<response>\n  <header>\n    <resultCode>00</resultCode>\n    <resultMsg>NORMAL SERVICE</resultMsg>\n  </header>\n  <body>\n    <items/>\n    <numOfRows>10</numOfRows>\n    <pageNo>1</pageNo>\n    <totalCount>0</totalCount>\n  </body>\n</response>\n'

# %%
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<response>\n  <header>\n    <resultCode>00</resultCode>\n    <resultMsg>NORMAL SERVICE</resultMsg>\n  </header>\n  <body>\n    <items/>\n    <numOfRows>10</numOfRows>\n    <pageNo>1</pageNo>\n    <totalCount>0</totalCount>\n  </body>\n</response>\n'

# %%
import requests

url = 'http://apis.data.go.kr/B190017/service/GetInsuredProductService202008/getProductList202008'
params ={'serviceKey' : 'ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D', 'pageNo' : '1', 'numOfRows' : '10', 'resultType' : 'xml', 'regnNm' : '금융투자', 'fncIstNm' : 'SK증권주식회사', 'prdNm' : '비과세장기회사채형' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
response.text
# Out:
# '<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
import requests

url = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList'
params ={'serviceKey' : 'ymBVj390b45Rr2hErpFD98uFKeYo77slk%2BRJivtZLyLgy7p67MbiBB9ohvVaIbqT2ewOk3DHoGJ2UCtmsFIW6g%3D%3D', 'pageNo' : '1', 'numOfRows' : '10', 'dataType' : 'XML', 'dataCd' : 'ASOS', 'dateCd' : 'DAY', 'startDt' : '20100101', 'endDt' : '20100601', 'stnIds' : '108' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
response.text
# Out:
# '<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'
