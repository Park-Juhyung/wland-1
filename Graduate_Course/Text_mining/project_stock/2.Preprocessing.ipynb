# %% [markdown]
# 엑셀 날짜변환
#
# https://thrillfighter.tistory.com/461

# %% [markdown]
# 텍스트 파일 합치기
#
# https://symin.tistory.com/188

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import csv

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

def cleanText(readData):
     
    remove_non_stopwords = re.compile('[一-龥]|[ぁ-ゔ]+|[ァ-ヴー]+[々〆〤]|ဏ|ဘ|ᄋᆻ|ု|း|〃|၀|ေ|္|ိ|–|သ|၉|န|င|မ|〈|၊|₿|ဒ|劉|利|်|ä|連|⚫|ｇ|â|χ|ဥ|㏄|ဗ|၎|၅|ဌ|㏊.|ü|◐|၁|⑬|，|ⅰ|샅|á|龜|[а-яА-Я]|‑|၆|ß|é|၄|6|⇒|◼|⠂|禮|ㅡ|і|ă|ș|タビヒト|カッパ|ハーモニッボーダレス|閭|沈|デーイタ|ⅴ|ニッポン|û|ã|ê|\s+(?P<NAME>\w+)\s+기자|(?:[a-zA-Z])+|⑶|🎧|金|တပြုလုပ်နေသူတစ်ဦးကဆိုသည်။|ạ|ⓝ|㉠|➋|➊|》|ကိုဗစ်|令|※|‧|∼|훑|不|│|²|㎢|ⅱ|♡|·|＂|｣|｢|＞|ⓒ|＋|老|女|勞|樂|樂|臨|六|茶|è|〕|♢|↔|₂|é|㎘|㎛|%..|′|＇|量|瑩|≪|β|亂|♬|聯|쨍|良|宅|栗|零|°|＊|☜|梨|烈|柳|靈|論|率|⟶|洛|露|ø|〜|〮|ｔ|í|㎚|蓮|復|里|ⓑ|㉤|壟|律|裸|溺|朗|ú|。|˙|ᆞ|㎧|ō|力|ó|å|凌|藍|裂|ⅵ|တရားဝင်|ù|ē|စတုတ္ထပတ်အတွင်းတွင်ကိုဗစ်|″|櫓|ရေးနှင့်အားကစားဝန်ကြီးဌာန|်း၏၄၀ရာခိုင်နှုန်းရှိသည်။|蘆|ာမျက်နှာတွင်ရေးသားထားသည်။|예예|တကယ်သေဆုံးသူစာရင်းကွာခြား|뇽|參|긔|麗|ရန်ကုန်မြို့တွင်|㎗|몐|휀|寧|羅|數|¡|㉥|윷|ʼ|⑰|〔〕|므|곌|ヶ|領|ỳ|）.|燐|狀|ìè|ā|ケ|ミリガ|チングルマ|シナノキンバイ|イワイチョウ|スアップ|ベ|❹|エネルギー|ⓐ|ậ|⑳|⑲|⑱|⑯|離|ガリガリ|塞|ိသုဿန်စာရင်းများအရသိရသည်။|累|∙〔|＄|≥|ㅇㅇㅇ|驪|硫|i̇|㎠|ǐ|ī|≒|éè|ế|ñ|섧|廉|앟|¡°|炙|㎜.|、|‧‧|ω|₁|アイボン|例|%‥|暴|ㅄ|솅|챦|※「|車|蠟|陵|ノ|串|呂|햋|惡|怒|ⅴ|便|츄츄|類|糧|奈|寧|煉|駱|狼|カツ|コマツ|륏|ｓ|⬥|1⁺|龜|ǔ|ě|×××|：：|².|》.|ニセコ|ää|랲|ȋ|î|樂|ဆေးကုသရေးဘယ်မှာလဲ|ပွဲစျေးတန်သဖွယ်ဖြစ်နေသည်။|ါက်ကဲ့သို့သဖွယ်ဖြစ်နေသည်။|야야야|쟉|롈|ပဲရရာဆေးနဲ့ကုရတော့တာပါပဲ။|ည့်လူငယ်တစ်ဦးကရှင်းပြသည်။|『.|뗴|ⅳ|⭐|▦|퉤|에에에에에에|မ်းမှုအပြီးပြိုလဲသွားသည်။|拉|븟|ရေးပေါ်ကုသမှုလိုသောကိုဗစ်|쳰|\d{4}.\d{2}.\d{2}.|č|š|擄|＿|끽끽|풂|フリーター|倫|ギャラガ|└|錄|隆|泌|祿|琉|ブラッ|곻|北|隣|ㅎㅎㅎ|ㆆ|ホルモン|ㆁ|페릴아세테이트와산자나무열매추출물이|歷|른달러강세시헤알화가치폭락가능성도있다|㏉|コメ|オレオレ|賈|▫|裏|ヤマト|˚|ラ|プロ|ジャテッ|èé|㎐|묾|¨|㉯|ⓔ|？？？？？|ìì|쥰|。|æ|ở|懶|？？？？|⑺|樂樂|➅|\d{4}.\d{1}.\d{2}|切|ံလောက်မှုများဖြစ်ပေါ်သည်။|コト|츌|ာရှင်းလင်းပွဲတွင်ပြောသည်။|ာ်လင့်ချက်ကင်းမဲ့နေကြသည်။|%＋|ｏｋ|ｍｍｔ|ုးနှံမှုကိုမပြုလုပ်ကြချေ။|オタ|쫀|ဆိုသော်လည်းဇူလိုင်လအထိလူ၁|ှာ၅ဆနီးပါးထိုးတက်သွားသည်။|뺼|်စျေးနှုန်းစီးပွားရေးဂယက်|²%|ㅏ원|뵤|バカ|ာက်ကုန်တွေလဲတက်ကုန်တာပေါ့|호호호호|ㅆ가|ｅ|.%|뵨|줴|ᆞ|㵳|淚|玲|\d{4}|ㅃ깹ㅏ|\d{4} .|スパイラル|\d{2} .|㉜|\d{4}.\d{1}.\d{1}|ạ|⑴|\d{13}|ㅠㅠㅠㅠ|\d{14}|➁|➂|\d{15}|¼∼½|\d{16}|\d{18}|\d{15}|\d{2} \d{3} \d{4}|➌|ạ|¿|ω|ё|\d{2} \d{2}|ⓓ|————————|➀|➌|ⓐ|㈔|鍊|서울 뉴시스|兩|서울 연합뉴스|¾|㉠∼㉢|%〕|㉠＋㉢|×××××|××××|⓺|±|ㅜㅜㅋ|뉴욕 연합뉴스|뉴시스|앵커|《|⊙|뉴스 가치나 화제성이 있다고 판단되는 사진 또는 영상을|로 보내주시면 적극 반영하겠습니다.|사진영상부|√|한겨레|동아일보|헤럴드경제|جنات|서울신문|မြန်မာဘာသာ|아이뉴스 24|➃|說|헤럴드경제|ကိုဗစ်ကပ်ဘေးနဲ့ရန်ကုန်|뉴스1|ø|한국경제신문|머니투데이|이데일리|아시아경제|서울 연합뉴스|①|②|③|④|⑤|⑥|⑦|⑧|⑨|⑩|⑪|⑫|❶|❷|㈜|❸|➍|مملكة|㉡|㉢|㉣|≠|率|ㅈㅚㅌ|ǎ|ū|ㅡ기사|（|⅔|樓|蘭|省|¼|ⓛ|로이터|본문|이미지 영역|āḫ|㴭|이브닝뉴스|ွင်မြန်မာနိုင်ငံသည်ကိုဗစ်|합천 연합뉴스|\d{6}|မြားကူးစက်ကာသေဆုံးကြရသည်။|본문 이미지 영역|노컷뉴스|사진 출처|က်တိုင်မှာနာရေးအိမ်ရှိတယ်|뉴스투데이|그래픽 뉴스|အောက်ဆိုးရွားလွန်းခဲ့သည်။|연합뉴스|［|］|သွားကြည့်မှသေနေတာတွေ့တယ်။|게티이미지|များပင်ဒုနဲ့ဒေးဖြစ်နေသည်။|來|ွ|사진 영상 제보받습니다|독자 여러분의 소중한 제보를 기다립니다|보내주시면 적극 반영하겠습니다.|泥|「|×|ြ|공감언론|李|တ|年|◯◯|ᾶ|ν|ῆ|μος|聾|㉠∼㉣|糖|်မရရှိတော့ဘဲလုပ်ငန်းများ၊|ồ|ြို့နေပြည်သူတစ်ဦးကဆိုသည်။|ư|ီဂျင်အိုးများ၊အောက်ဆီဂျင်|ấ|ိုင်းခွေးအူသံတွေကြားရတယ်။|ổ|劣|င်းခွေးအူသံများကြာနေရသည်။|ါစျေးတက်သွားခြင်းဖြစ်သည်။|⅓|ပါးနာရေးအိမ်လွတ်တာမရှိဘူး|⅔|烙|သူများမနည်းမနောရှိခဲ့သည်။|ё|းခန့်သာရှိသည်။အောက်ဆီဂျင်|浪|ö|廬|ý|紐|螺|礪|螺|寮|ｏｋ|ｍｍｔ|восто|⓺|ð|1319317095950518405513226|спасибо|《※|─────────|─────────────────────────|落|ရွယ်ရှိလူငယ်တစ်ဦးကဆိုသည်။|⑮|ျောက်၊နေမကောင်းသည့်လူများ|―〈|麟|理|ž|盧|遼|爛|⓶|ဉ|遼|à|ố|‰|ှင့်ကပ်ဘေးဂယက်များကြောင့်|ㅜㅡㅜ|поехали|ố|ဍ|�|ကမ္ဘာ့ဘဏ်ကကိုဗစ်|ḫ|⓷|ခ|ီ|ံ|쐈|ယ|ထ|ါ|ⅲ|／|ဖ|㎥|ペン|ြည့်မှုအစီရင်ခံစာကဆိုသည်။|≠？|『.』|ク|ည|¼∼½|داملا|㉦|အဆိုးထဲကအကောင်းလား|冷|㉮|دهဆ|———————|樂樂|ⓒ|〈〉|ملا|∽|囹|豈')
    remove_non_stopwords2 = re.compile('\s+(?P<NAME>\w+)\s+연합뉴스')
    extra_special_char = re.compile('·|“|”|‘|’|ㆍ|… |•|…|▷|→|☞|₤|↑|☏|←|○|㎦|＠|●|♠|▴|◇|▽|↓|†|┫|□|§|⓵|◎|⓸|㉚|㊤|♥|★|』|◈|㎍|㎝|•|･|φ|∙|㎾|」|♧|弄|∆|・|～|↗|췌|㎒|▪|㎈|ℓ|μ|½|\s+|㎉|➝|￦|£|㎸|π|￥|©|㊦|‱|™|Ⓡ|®|➡|△|⇢|㎖|㎏|㎞|㎡|⊂|❏|∞|€|▨|ⓒ|⑷|▣|━|▼|＃|―|ㅿ|☎|￭|├|┼|┤|㎿|♦|℃|㎓|➎|￡|►|⟶|╂|ⓡ|♨|θ|㎽|‣|↖|◊|⋯|㎤|฿|┌|┬|┐|ứ|㎢.|▮|◑|♣|↘|❍|＆|＜')
    
    file_lst_trimmed = [re.sub(remove_non_stopwords, '', str(file))for file in readData]
    file_lst_trimmed2 = [re.sub(remove_non_stopwords2, '', str(file))for file in file_lst_trimmed]
    file_lst_trimmed3 = [re.sub(extra_special_char, ' ', str(file))for file in file_lst_trimmed2]
    file_lst_trimmed4 = list(map(str.lstrip, file_lst_trimmed3))
    return file_lst_trimmed4

# %%
df = pd.read_csv("/Users/seoinjae/OneDrive - 연세대학교 (Yonsei University)/2021-2학기/2.텍스트마이닝/텀프로젝트/기사 크롤링/pre_data/merged_주식.txt", header=None,sep='\t', encoding = 'utf-8-sig')
df.head()
# Out:
#          0                     1  \
# 0     전자신문  2020.11.01. 오전 12:01
# 1      뉴스엔  2020.11.01. 오전 12:39
# 2  SBS연예뉴스   2020.11.01. 오전 2:07
# 3     연합뉴스   2020.11.01. 오전 5:00
# 4      머니S   2020.11.01. 오전 5:33
#
#                                                    2  \
# 0  https://news.naver.com/main/read.naver?mode=LS...
# 1  https://news.naver.com/main/read.naver?mode=LS...
# 2  https://news.naver.com/main/read.naver?mode=LS...
# 3  https://news.naver.com/main/read.naver?mode=LS...
# 4  https://news.naver.com/main/read.naver?mode=LS...
#
#                                                    3  \
# 0  전화성의 기술창업 Targeting 142. 스타트업 창업자가 배워야 할 故 이건희...
# 1               ‘그알’ 계층이동 사다리 된 주식 우리나라 주식시장은 공정할까종합
# 2  스브스夜 그것이 알고싶다 소액주주는 재산을 잃고 MB는 법의 불공정을 외치는 사회…...
# 3                       댓글조작 혐의 김경수 경남지사 이번 주 항소심 선고
# 4                                고수칼럼 세계 8대 불가사의는 복리
#
#                                                    4
# 0  재계의 큰 별이 졌다. 해외에서 장기간 체류했던 사람이라면 누구나 1990년대 이후...
# ...

# %%
df.columns = ['1','Date','2','3','Content']

# %%
df['Content'] = cleanText(df['Content'])

# %%
df.head()
# Out:
#          1                  Date  \
# 0     전자신문  2020.11.01. 오전 12:01
# 1      뉴스엔  2020.11.01. 오전 12:39
# 2  SBS연예뉴스   2020.11.01. 오전 2:07
# 3     연합뉴스   2020.11.01. 오전 5:00
# 4      머니S   2020.11.01. 오전 5:33
#
#                                                    2  \
# 0  https://news.naver.com/main/read.naver?mode=LS...
# 1  https://news.naver.com/main/read.naver?mode=LS...
# 2  https://news.naver.com/main/read.naver?mode=LS...
# 3  https://news.naver.com/main/read.naver?mode=LS...
# 4  https://news.naver.com/main/read.naver?mode=LS...
#
#                                                    3  \
# 0  전화성의 기술창업 Targeting 142. 스타트업 창업자가 배워야 할 故 이건희...
# 1               ‘그알’ 계층이동 사다리 된 주식 우리나라 주식시장은 공정할까종합
# 2  스브스夜 그것이 알고싶다 소액주주는 재산을 잃고 MB는 법의 불공정을 외치는 사회…...
# 3                       댓글조작 혐의 김경수 경남지사 이번 주 항소심 선고
# 4                                고수칼럼 세계 8대 불가사의는 복리
#
#                                              Content
# 0  재계의 큰 별이 졌다. 해외에서 장기간 체류했던 사람이라면 누구나 년대 이후 고 이...
# ...

# %%
df.to_csv("/Users/seoinjae/OneDrive - 연세대학교 (Yonsei University)/2021-2학기/2.텍스트마이닝/텀프로젝트/데이터셋/코스피_정제_20201101_20211031/주식_정제_20201101_20211031.csv", index = None, encoding = 'utf-8-sig')

# %% [markdown]
# ## 200글자 이하 제거

# %%
aticle = "국내 주식시장이 3일 상승세로 출발했다. 코스피 지수는 전날보다 15.5포인트 0. 오른 .81에 거래를 시작했다. 코스닥 지수는 7.0포인트 0.8 상승한 810.01에 장을 시작했다."

# %%
sentence = "경향신문 요즘 들어 스웨덴에 정말 상속세가 없느냐고 물어오는 이가 많다. 스웨덴은 높은 세율과 복지를 통해 강력한 부의 재분배를 이룬 나라로 알려져 있다. 소득분위가 마름모꼴로 중산층이 강하고 엄청난 부자나 찢어지게 가난한 인구가 적다. 한 사회의 불평등 정도를 나타내는 지니계수를 보면 스웨덴의 경우 세전 0.434에서 세후 0.275로 떨어진다. 지니계수가 0.3 이하이면 매우 평등한 사회라고 보는데 한국은 세전 0.4후 0.355다. 세전과 세후 차이를 보면 소득재분배 정도를 알 수 있는데 스웨덴의 경우 효과적으로 중산층을 강화해왔다고 볼 수 있다. 하수정 북유럽연구자 이런 스웨덴에 특이하게도 상속세가 없다. 그러니 한국도 상속세를 없애야 한다고 주장하면 곤란하다. 두 나라의 조세 징수 현황이 다르기 때문이다. 스웨덴은 세금 징수율이 9에 이르는 나라로 세금을 올리겠다는 공약을 내걸어도 당선이 되는 나라다. 대학시절 내 친구들은 주말에 아르바이트를 해서 번 돈을 국세청에 자발적으로 신고했다. 퀴즈대회에서 우승해 상금으로 50만크로나 약 만원 를 받은 후 3를 세금으로 낸 친구에게 아깝지 않으냐 물으니 자신은 지금껏 사회가 제공하는 복지를 누리기만 했다며 이제 기여할 수 있어 기쁘다고 했다. 세금은 복지국가의 엔진이라 탈세는 사회의 근간을 흔드는 일로 여긴다. 유명인사의 인터뷰를 보면 한결같이 사회가 제공한 인프라와 복지가 없었으면 자신의 성공은 불가능했을 것이라고 답한다. 세금을 포탈하면 매국노 취급을 받는 사회다. 국제탐사보도언론인협회 는 년 세계 7개국의 언론사가 참여해 전 세계 부자와 다국적기업의 조세도피 관련 문서를 분석한  파라다이스 페이퍼스 를 공개했다. 보고서에는 한국인 232명과 이들이 세운 유령회사 거래 내역이 포함되어 있다. 한국은 중국 러시아와 함께 조세포탈액이 큰 나라 중 하나로 분류됐는데 액수나 순위의 정확함은 따져봐야겠지만 한국 부자의 조세회피 내역이 상당할 것이라는 짐작은 할 수 있다. 국세청 조세 통계에 따르면 한국의 경우 년부터 년까지 재산을 상속받은 274만명 가운데 1.만이 상속세를 납부했다고 한다. 다양한 방법으로 공제받을 수 있기 때문이다. 상속세 폐지를 말하기 전에 상속세가 제 역할을 해왔는지 평소 탈세 없이 세금을 잘 냈는지 조사부터 해야 하는 것 아닌가 싶다. 그럼 스웨덴은 왜 상속세를 폐지했을까 전체 세액에서 상속세 비율이 0.3 정도로 미미했기 때문이다. 스웨덴 중산층은 이미 소득의 상당 부분을 세금으로 납부하고 노후엔 연금으로 생활이 보장되기에 부를 엄청나게 축적하는 사례가 많지 않다. 남길 재산이라고 해봐야 살던 집 좀 더 여유가 있으면 요트 정도인데 과거 스웨덴의 상속세 최대 구간이 로 세금을 현금으로 내야 하니 평소 상당한 여윳돈을 비축하지 않은 이상 상속세를 내기 위해 상속받은 재산을 바로 팔거나 빚을 내야 했다. 그러다 보니 중산층에서 상속세의 불합리성에 대해 지적하고 나온 것이다. 보수정권이 아닌 사민당 정권이 상속세 폐지를 추진한 이유다. 스웨덴의 상속세 폐지는 재벌이 아닌 평범한 다수를 위한 것이었다. 스웨덴에 상속세는 없지만 자본이득세가 있다. 상속받은 재산 자체에는 세금을 매기지 않지만 상속 재산을 처분하는 시점 즉 상속받은 주식 채권 부동산 등을 매각하는 시점에 발생하는 이익에 과세하는 것으로 양도소득세와 비슷한 개념이다. 경제가 일정 규모 이상 발전한 여러 나라에서 도입하고 있는 제도다. 스웨덴은 한국과 비슷하게 대기업 중심의 산업구조라 몇 개의 기업가문이 스웨덴 경제를 구성한다. 안정적으로 소유권을 유지하고 경영권을 보장받게 된 이들 가문은 정부와 일종의 신사협약을 맺어 기업의 사회보험료를 높이고 사회환원을 활발히 해왔다. 스웨덴 주식시장 시가총액의 4를 소유한 발렌베리를 비롯한 주요 가문은 개인이 아닌 재단을 통해 재산을 소유하기 때문에 개별 자산은 몇 백억원 수준으로 한국의 재벌 2세에 비하면 약소하다. 스웨덴 재계의 문화를 선도하는 발렌베리 가문의 모토는  스웨덴을 위해서 다. 소유 기업에서 발생한 수익 대부분이 재단으로 들어가는데 발렌베리재단은 스웨덴 학문의 후원자로 노벨상 연구 중에 발렌베리재단의 후원을 안 받은 경우가 없다고 할 정도다. 자연과학에 비해 연구기금이 부족한 인문사회 연구 특히 평화 분쟁조정 사회통합 연구에 후원을 아끼지 않는다. 세금은 최소한의 장치다. 상속세 폐지 여부는 제반 상황을 비슷하게 맞춘 후에 다시 이야기해도 늦지 않을 것이다."

# %%
sentence = '국내 주식시장이 3일 상승세로 출발했다. 코스피 지수는 전날보다 15.5포인트 0. 오른 .81에 거래를 시작했다. 코스닥 지수는 7.0포인트 0.8 상승한 810.01에 장을 시작했다.'

# %%
sentence = '국내 주식형 펀드 자금이 5거래일 만에 순유출로 전환됐다. 17일 금융투자협회에 따르면 지난 15일 기준 국내 주식형 펀드 상장지수펀드 제외 에서 309억원이 설정되고 722억원이 해지돼 413억원이 순유출됐다. 사진 이미지투데이 또 해외 주식형 펀드에서는 15억원이 설정되고 44억원이 해지돼 30억원이 순유출됐다. 하루만에 순유출 전환이다. 국내 외 주식형 펀드 설정원본은 85조억원으로 전 거래일보다 35억원 줄었다. 설정원본에 운용 손익을 더한 순자산총액은 101조284억원으로 전 거래일보다 억원 감소했다. 국내 외 채권형 펀드 설정원본은 131조억원으로 전 거래일보다 억원 줄었다. 순자산총액은 131조억원으로 전 거래일보다 억원 감소했다. 단기금융상품인 머니마켓펀드 설정원본은 153조억원으로 전 거래일보다 억원 증가했다. 순자산총액은 154조억원으로 전 거래일보다 억원 증가했다.'

# %%
len(sentence)
# Out:
# 2184

# %%
aticle
# Out:
# '국내 주식시장이 3일 상승세로 출발했다. 코스피 지수는 전날보다 15.5포인트 0. 오른 .81에 거래를 시작했다. 코스닥 지수는 7.0포인트 0.8 상승한 810.01에 장을 시작했다.'

# %% [markdown]
# ## TEST

# %%
df_test = pd.DataFrame({'날짜' : ['2020.11.1', '2020.11.2', '2020.11.3','2020.11.4'],
                        '본문'  : ['경향신문 요즘 들어 스웨덴에 정말 상속세가 없느냐고 물어오는 이가 많다. 스웨덴은 높은 세율과 복지를 통해 강력한 부의 재분배를 이룬 나라로 알려져 있다. 소득분위가 마름모꼴로 중산층이 강하고 엄청난 부자나 찢어지게 가난한 인구가 적다. 한 사회의 불평등 정도를 나타내는 지니계수를 보면 스웨덴의 경우 세전 0.434에서 세후 0.275로 떨어진다. 지니계수가 0.3 이하이면 매우 평등한 사회라고 보는데 한국은 세전 0.4후 0.355다. 세전과 세후 차이를 보면 소득재분배 정도를 알 수 있는데 스웨덴의 경우 효과적으로 중산층을 강화해왔다고 볼 수 있다. 하수정 북유럽연구자 이런 스웨덴에 특이하게도 상속세가 없다. 그러니 한국도 상속세를 없애야 한다고 주장하면 곤란하다. 두 나라의 조세 징수 현황이 다르기 때문이다. 스웨덴은 세금 징수율이 9에 이르는 나라로 세금을 올리겠다는 공약을 내걸어도 당선이 되는 나라다. 대학시절 내 친구들은 주말에 아르바이트를 해서 번 돈을 국세청에 자발적으로 신고했다. 퀴즈대회에서 우승해 상금으로 50만크로나 약 만원 를 받은 후 3를 세금으로 낸 친구에게 아깝지 않으냐 물으니 자신은 지금껏 사회가 제공하는 복지를 누리기만 했다며 이제 기여할 수 있어 기쁘다고 했다. 세금은 복지국가의 엔진이라 탈세는 사회의 근간을 흔드는 일로 여긴다. 유명인사의 인터뷰를 보면 한결같이 사회가 제공한 인프라와 복지가 없었으면 자신의 성공은 불가능했을 것이라고 답한다. 세금을 포탈하면 매국노 취급을 받는 사회다. 국제탐사보도언론인협회 는 년 세계 7개국의 언론사가 참여해 전 세계 부자와 다국적기업의 조세도피 관련 문서를 분석한  파라다이스 페이퍼스 를 공개했다. 보고서에는 한국인 232명과 이들이 세운 유령회사 거래 내역이 포함되어 있다. 한국은 중국 러시아와 함께 조세포탈액이 큰 나라 중 하나로 분류됐는데 액수나 순위의 정확함은 따져봐야겠지만 한국 부자의 조세회피 내역이 상당할 것이라는 짐작은 할 수 있다. 국세청 조세 통계에 따르면 한국의 경우 년부터 년까지 재산을 상속받은 274만명 가운데 1.만이 상속세를 납부했다고 한다. 다양한 방법으로 공제받을 수 있기 때문이다. 상속세 폐지를 말하기 전에 상속세가 제 역할을 해왔는지 평소 탈세 없이 세금을 잘 냈는지 조사부터 해야 하는 것 아닌가 싶다. 그럼 스웨덴은 왜 상속세를 폐지했을까 전체 세액에서 상속세 비율이 0.3 정도로 미미했기 때문이다. 스웨덴 중산층은 이미 소득의 상당 부분을 세금으로 납부하고 노후엔 연금으로 생활이 보장되기에 부를 엄청나게 축적하는 사례가 많지 않다. 남길 재산이라고 해봐야 살던 집 좀 더 여유가 있으면 요트 정도인데 과거 스웨덴의 상속세 최대 구간이 로 세금을 현금으로 내야 하니 평소 상당한 여윳돈을 비축하지 않은 이상 상속세를 내기 위해 상속받은 재산을 바로 팔거나 빚을 내야 했다. 그러다 보니 중산층에서 상속세의 불합리성에 대해 지적하고 나온 것이다. 보수정권이 아닌 사민당 정권이 상속세 폐지를 추진한 이유다. 스웨덴의 상속세 폐지는 재벌이 아닌 평범한 다수를 위한 것이었다. 스웨덴에 상속세는 없지만 자본이득세가 있다. 상속받은 재산 자체에는 세금을 매기지 않지만 상속 재산을 처분하는 시점 즉 상속받은 주식 채권 부동산 등을 매각하는 시점에 발생하는 이익에 과세하는 것으로 양도소득세와 비슷한 개념이다. 경제가 일정 규모 이상 발전한 여러 나라에서 도입하고 있는 제도다. 스웨덴은 한국과 비슷하게 대기업 중심의 산업구조라 몇 개의 기업가문이 스웨덴 경제를 구성한다. 안정적으로 소유권을 유지하고 경영권을 보장받게 된 이들 가문은 정부와 일종의 신사협약을 맺어 기업의 사회보험료를 높이고 사회환원을 활발히 해왔다. 스웨덴 주식시장 시가총액의 4를 소유한 발렌베리를 비롯한 주요 가문은 개인이 아닌 재단을 통해 재산을 소유하기 때문에 개별 자산은 몇 백억원 수준으로 한국의 재벌 2세에 비하면 약소하다. 스웨덴 재계의 문화를 선도하는 발렌베리 가문의 모토는  스웨덴을 위해서 다. 소유 기업에서 발생한 수익 대부분이 재단으로 들어가는데 발렌베리재단은 스웨덴 학문의 후원자로 노벨상 연구 중에 발렌베리재단의 후원을 안 받은 경우가 없다고 할 정도다. 자연과학에 비해 연구기금이 부족한 인문사회 연구 특히 평화 분쟁조정 사회통합 연구에 후원을 아끼지 않는다. 세금은 최소한의 장치다. 상속세 폐지 여부는 제반 상황을 비슷하게 맞춘 후에 다시 이야기해도 늦지 않을 것이다.'
                                 ,'국내 주식시장이 3일 상승세로 출발했다. 코스피 지수는 전날보다 15.5포인트 0. 오른 .81에 거래를 시작했다. 코스닥 지수는 7.0포인트 0.8 상승한 810.01에 장을 시작했다.'
                                 ,'다음은 1일 장 마감 후 주요 종목뉴스다.'
                                 ,'국내 주식형 펀드 자금이 5거래일 만에 순유출로 전환됐다. 17일 금융투자협회에 따르면 지난 15일 기준 국내 주식형 펀드 상장지수펀드 제외 에서 309억원이 설정되고 722억원이 해지돼 413억원이 순유출됐다. 사진 이미지투데이 또 해외 주식형 펀드에서는 15억원이 설정되고 44억원이 해지돼 30억원이 순유출됐다. 하루만에 순유출 전환이다. 국내 외 주식형 펀드 설정원본은 85조억원으로 전 거래일보다 35억원 줄었다. 설정원본에 운용 손익을 더한 순자산총액은 101조284억원으로 전 거래일보다 억원 감소했다. 국내 외 채권형 펀드 설정원본은 131조억원으로 전 거래일보다 억원 줄었다. 순자산총액은 131조억원으로 전 거래일보다 억원 감소했다. 단기금융상품인 머니마켓펀드 설정원본은 153조억원으로 전 거래일보다 억원 증가했다. 순자산총액은 154조억원으로 전 거래일보다 억원 증가했다.'
                        ]
})

# %%
df_test
# Out:
#           날짜                                                 본문
# 0  2020.11.1  경향신문 요즘 들어 스웨덴에 정말 상속세가 없느냐고 물어오는 이가 많다. 스웨덴은 ...
# 1  2020.11.2  국내 주식시장이 3일 상승세로 출발했다. 코스피 지수는 전날보다 15.5포인트 0....
# 2  2020.11.3                            다음은 1일 장 마감 후 주요 종목뉴스다.
# 3  2020.11.4  국내 주식형 펀드 자금이 5거래일 만에 순유출로 전환됐다. 17일 금융투자협회에 따...

# %%
df_test['word_cont'] = df_test.본문.str.count('')-1

# %%
df_test
# Out:
#           날짜                                                 본문  word_cont
# 0  2020.11.1  경향신문 요즘 들어 스웨덴에 정말 상속세가 없느냐고 물어오는 이가 많다. 스웨덴은 ...       2184
# 1  2020.11.2  국내 주식시장이 3일 상승세로 출발했다. 코스피 지수는 전날보다 15.5포인트 0....        104
# 2  2020.11.3                            다음은 1일 장 마감 후 주요 종목뉴스다.         23
# 3  2020.11.4  국내 주식형 펀드 자금이 5거래일 만에 순유출로 전환됐다. 17일 금융투자협회에 따...        444

# %%
df_test_final = df_test[df_test.word_cont > 200]

# %%
df_test_final
# Out:
#           날짜                                                 본문  word_cont
# 0  2020.11.1  경향신문 요즘 들어 스웨덴에 정말 상속세가 없느냐고 물어오는 이가 많다. 스웨덴은 ...       2184
# 3  2020.11.4  국내 주식형 펀드 자금이 5거래일 만에 순유출로 전환됐다. 17일 금융투자협회에 따...        444

# %% [markdown]
# # 600자 이하 단어 제거

# %%
df_stock = pd.read_csv("C:/Users/ANDlab3/OneDrive - 연세대학교 (Yonsei University)/2021-2학기/2.텍스트마이닝/텀프로젝트/데이터셋/정제_20201101_20211031/2차/주식_정제_2차_20201101_20211031.csv"
                        ,sep=',',encoding = 'utf-8-sig')

# %%
df_kospi = pd.read_csv("C:/Users/ANDlab3/OneDrive - 연세대학교 (Yonsei University)/2021-2학기/2.텍스트마이닝/텀프로젝트/데이터셋/정제_20201101_20211031/2차/코스피_정제_2차_20201101_20211031.csv"
                        ,sep=',',encoding = 'utf-8-sig')

# %%
df_stock.head()
# Out:
#         Date                                            Content  word_cont
# 0  2020.11.1  재계의 큰 별이 졌다. 해외에서 장기간 체류했던 사람이라면 누구나 년대 이후 고 이...       1597
# 1  2020.11.1  이미지 원본보기 뉴스엔 계층 이동의 사다리가 된 주식 우리나라 주식시장은 공정할까 ...       2095
# 2  2020.11.1  이미지 원본보기 연예뉴스 김효정 에디터 매번 불어오는 돈의 열풍 속에서 세상은 나아...       4024
# 3  2020.11.1  입시비리 사모펀드 의혹 정경심 교수 결심 공판도 김경수 경남도지사 자료사진 댓글을 ...       1085
# 4  2020.11.1  효과적인 재테크 투자를 위해 복리를 잘 이용해야 한다는 주장이 나왔다. 다만 복리효...       2444

# %%
df_kospi.head()
# Out:
#          Date                                            Content  word_cont
# 0  2020-10-01  카카오게임즈 대비 주식수 적어 높은 경쟁률 예상 주관사별 주식수 고려해 청약하는 것...       1337
# 1  2020-10-01  오는 11월 미국 대선을 한 달여 앞둔 가운데 시장의 변동성 확대가 우려되고 있다....       1040
# 2  2020-10-01  수요예측 경쟁률 .25대 1 코스피 최대 공모가 기준 시총 4.조원 엔터 3사 합계...        772
# 3  2020-10-01  사진 이미지투데이 신종 코로나바이러스 감염증 코로나파 이후 국내 증시를 주도한 바이...        881
# 4  2020-10-01  증시 전문가 조정국면 박스권 장세 전망 우세 단기조정 주도주 매수 기회 2차전지 제...       2560

# %%
df_stock['word_cont'] = df_stock.Content.str.count('')-1

# %%
df_kospi['word_cont'] = df_kospi.Content.str.count('')-1

# %%
df_stock.head()
# Out:
#         Date                                            Content  word_cont
# 0  2020.11.1  재계의 큰 별이 졌다. 해외에서 장기간 체류했던 사람이라면 누구나 년대 이후 고 이...       1597
# 1  2020.11.1  이미지 원본보기 뉴스엔 계층 이동의 사다리가 된 주식 우리나라 주식시장은 공정할까 ...       2095
# 2  2020.11.1  이미지 원본보기 연예뉴스 김효정 에디터 매번 불어오는 돈의 열풍 속에서 세상은 나아...       4024
# 3  2020.11.1  입시비리 사모펀드 의혹 정경심 교수 결심 공판도 김경수 경남도지사 자료사진 댓글을 ...       1085
# 4  2020.11.1  효과적인 재테크 투자를 위해 복리를 잘 이용해야 한다는 주장이 나왔다. 다만 복리효...       2444

# %%
df_kospi.head()
# Out:
#          Date                                            Content  word_cont
# 0  2020-10-01  카카오게임즈 대비 주식수 적어 높은 경쟁률 예상 주관사별 주식수 고려해 청약하는 것...       1337
# 1  2020-10-01  오는 11월 미국 대선을 한 달여 앞둔 가운데 시장의 변동성 확대가 우려되고 있다....       1040
# 2  2020-10-01  수요예측 경쟁률 .25대 1 코스피 최대 공모가 기준 시총 4.조원 엔터 3사 합계...        772
# 3  2020-10-01  사진 이미지투데이 신종 코로나바이러스 감염증 코로나파 이후 국내 증시를 주도한 바이...        881
# 4  2020-10-01  증시 전문가 조정국면 박스권 장세 전망 우세 단기조정 주도주 매수 기회 2차전지 제...       2560

# %%
df_kospi_final = df_kospi[df_kospi.word_cont > 600]

# %%
df_stock_final = df_stock[df_stock.word_cont > 600]

# %%
df_kospi_final.head()
# Out:
#          Date                                            Content  word_cont
# 0  2020-10-01  카카오게임즈 대비 주식수 적어 높은 경쟁률 예상 주관사별 주식수 고려해 청약하는 것...       1337
# 1  2020-10-01  오는 11월 미국 대선을 한 달여 앞둔 가운데 시장의 변동성 확대가 우려되고 있다....       1040
# 2  2020-10-01  수요예측 경쟁률 .25대 1 코스피 최대 공모가 기준 시총 4.조원 엔터 3사 합계...        772
# 3  2020-10-01  사진 이미지투데이 신종 코로나바이러스 감염증 코로나파 이후 국내 증시를 주도한 바이...        881
# 4  2020-10-01  증시 전문가 조정국면 박스권 장세 전망 우세 단기조정 주도주 매수 기회 2차전지 제...       2560

# %%
df_stock_final.head()
# Out:
#         Date                                            Content  word_cont
# 0  2020.11.1  재계의 큰 별이 졌다. 해외에서 장기간 체류했던 사람이라면 누구나 년대 이후 고 이...       1597
# 1  2020.11.1  이미지 원본보기 뉴스엔 계층 이동의 사다리가 된 주식 우리나라 주식시장은 공정할까 ...       2095
# 2  2020.11.1  이미지 원본보기 연예뉴스 김효정 에디터 매번 불어오는 돈의 열풍 속에서 세상은 나아...       4024
# 3  2020.11.1  입시비리 사모펀드 의혹 정경심 교수 결심 공판도 김경수 경남도지사 자료사진 댓글을 ...       1085
# 4  2020.11.1  효과적인 재테크 투자를 위해 복리를 잘 이용해야 한다는 주장이 나왔다. 다만 복리효...       2444

# %%
df_stock_final.to_csv("C:/Users/ANDlab3/OneDrive - 연세대학교 (Yonsei University)/2021-2학기/2.텍스트마이닝/텀프로젝트/데이터셋/정제_20201101_20211031/3차/주식_정제_3차_20201101_20211031.csv" ,index = None, encoding = 'utf-8-sig')

# %%
df_kospi_final.to_csv("C:/Users/ANDlab3/OneDrive - 연세대학교 (Yonsei University)/2021-2학기/2.텍스트마이닝/텀프로젝트/데이터셋/정제_20201101_20211031/3차/코스피_정제_3차_20201101_20211031.csv" ,index = None, encoding = 'utf-8-sig')
