# %% [markdown]
# winemag-data.csv 파일을 reviews 로 읽는다.

# %%
import pandas as pd

# %%
reviews = pd.read_csv('winemag-data.csv',index_col=0)  # 1

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
# 인덱스 unnamed 0 없애는법 2

# %%
reviews = pd.read_csv('winemag-data.csv')

# %%
reviews.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1      Avidagos      87   15.0              Douro      NaN      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
reviews.loc[ : , 'country' : ]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
# 3

# %%
reviews.iloc[ : , 1: ] # 인덱스 unnamed 0 없애는법 3
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews.loc[ : , 'country': ]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
# 4

# %%
reviews.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1      Avidagos      87   15.0              Douro      NaN      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.drop("Unnamed: 0", axis=1) # 인덱스 unnamed 0 없애는법 4
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1      Avidagos      87   15.0              Douro      NaN      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
reviews = reviews.drop("Unnamed: 0", axis=1) # 저장1, 안하면 화면출력만함 위에결과
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-5d470d191ace> in <module>
# ----> 1 reviews = reviews.drop("Unnamed: 0", axis=1) # 저장1, 안하면 화면출력만함 위에결과
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
reviews.drop("Unnamed: 0", axis=1, inplace=True) #저장2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-99e7beafbf61> in <module>
# ----> 1 reviews.drop("Unnamed: 0", axis=1, inplace=True) #저장2
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %% [markdown]
# 인덱스를 title 컬럼으로 셋팅한다.

# %%
reviews.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
reviews = reviews.set_index("Unnamed: 0") #1 저장
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-73869fd90eff> in <module>
# ----> 1 reviews = reviews.set_index("Unnamed: 0") #1 저장
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['Unnamed: 0'] are in the columns"

# %%
reviews
# Out:
#              country                                        description  \
# Unnamed: 0
# 0              Italy  Aromas include tropical fruit, broom, brimston...
# 1           Portugal  This is ripe and fruity, a wine that is smooth...
# 2                 US  Tart and snappy, the flavors of lime flesh and...
# 3                 US  Pineapple rind, lemon pith and orange blossom ...
# 4                 US  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# 129966       Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967            US  Citation is given as much as a decade of bottl...
# 129968        France  Well-drained gravel soil gives this wine its c...
# 129969        France  A dry style of Pinot Gris, this is crisp with ...
# 129970        France  Big, rich and off-dry, this is powered by inte...
#
#                                        designation  points  price  \
# Unnamed: 0
# ...

# %%
reviews.set_index('title', inplace=True) #2 바로반영

# %%
reviews.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
# 나ddddddddddddddddddddddddddddddddddd

# %%
reviews['title']
# Out:
# 0                         Nicosia 2013 Vulkà Bianco  (Etna)
# 1             Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2             Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3         St. Julian 2013 Reserve Late Harvest Riesling ...
# 4         Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#                                 ...
# 129966    Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# 129967                    Citation 2004 Pinot Noir (Oregon)
# 129968    Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969        Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970    Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
# Name: title, Length: 129971, dtype: object

# %%
reviews = pd.read_csv('winemag-data.csv')

# %%
reviews.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1      Avidagos      87   15.0              Douro      NaN      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
reviews.drop('Unnamed: 0', axis=1, inplace=True) # unnamed 지웠으나, title이 인덱스가 안됨

# %%
reviews.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
reviews.set_index('title') #ㅇㅋ
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# ...

# %%
# 나 이렇게도 됨

# %%
reviews = pd.read_csv('winemag-data.csv',index_col='title')  
# title은 인덱스 되었으나, 새로 불러와서 다시 unnamed 남아있음, set_index하면됨

# %%
reviews.head(2)
# Out:
#                                                Unnamed: 0   country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                       0     Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)           1  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# ...

# %%
reviews.drop('Unnamed: 0', axis=1, inplace=True)

# %%
reviews.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %% [markdown]
# ## 먼저 데이터가 비어있느것이 있는지 확인한다.

# %%
reviews.isna() # 나
# Out:
#         country  description  designation  points  price  province  region_1  \
# 0         False        False        False   False   True     False     False
# 1         False        False        False   False  False     False      True
# 2         False        False         True   False  False     False     False
# 3         False        False        False   False  False     False     False
# 4         False        False        False   False  False     False     False
# ...         ...          ...          ...     ...    ...       ...       ...
# 129966    False        False        False   False  False     False      True
# 129967    False        False         True   False  False     False     False
# 129968    False        False        False   False  False     False     False
# 129969    False        False         True   False  False     False     False
# 129970    False        False        False   False  False     False     False
#
# ...

# %%
reviews.isna().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# variety                      1
# winery                       0
# dtype: int64

# %% [markdown]
# ## 그리고나서, 가격이 없는 데이터는 빼고, 데이터셋을 가져온다.

# %%
reviews.head(2)
# Out:
#                                                Unnamed: 0   country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                       0     Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)           1  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# ...

# %%
reviews['price'].notna()
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                        False
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                             True
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                             True
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                       True
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                       True
#                                                                                                          ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (Mosel)     True
# Citation 2004 Pinot Noir (Oregon)                                                                         True
# ...

# %%
reviews.loc[ reviews['price'].notna(), ] # prcie 다있따
# Out:
#                                                      country  \
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...     Spain
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...

# %%
reviews.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
reviews.notna() # 데이터 있는것만 true
# Out:
#         country  description  designation  points  price  province  region_1  \
# 0          True         True         True    True  False      True      True
# 1          True         True         True    True   True      True     False
# 2          True         True        False    True   True      True      True
# 3          True         True         True    True   True      True      True
# 4          True         True         True    True   True      True      True
# ...         ...          ...          ...     ...    ...       ...       ...
# 129966     True         True         True    True   True      True     False
# 129967     True         True        False    True   True      True      True
# 129968     True         True         True    True   True      True      True
# 129969     True         True        False    True   True      True      True
# 129970     True         True         True    True   True      True      True
#
# ...

# %% [markdown]
# ## 리뷰에 새로운 컬럼 critic 만들고, everyone 이라고 값 넣는다.

# %%
reviews.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
reviews['critic'] = 'everyone'

# %%
reviews.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery    critic
# 0     White Blend              Nicosia  everyone
# 1  Portuguese Red  Quinta dos Avidagos  everyone

# %%
reviews['critic'] = ['everyone']  #22222222222222222222222222222222222 # 나

# %% [markdown]
# ## 리뷰의 포인트 컬럼은 수치로 되어있다. 이 컬럼의 기초통계데이터를 확인하시오. (평균, 최대 최소 등)

# %%
reviews['points']  # 값다름 title ~
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                        87
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                            87
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                            87
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                      87
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                      87
#                                                                                                          ..
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (Mosel)    90
# Citation 2004 Pinot Noir (Oregon)                                                                        90
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)                                                       90
# ...

# %%
reviews['points'] .describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
reviews.describe() # 나
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %% [markdown]
# ## 점수를 100점 맞은 와인의 데이터를 가져오시오.

# %%
reviews['points'] ==100
# Out:
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                                                                        False
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                                                            False
# Rainstorm 2013 Pinot Gris (Willamette Valley)                                                            False
# St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)                                      False
# Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)                      False
#                                                                                                          ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (Mosel)    False
# Citation 2004 Pinot Noir (Oregon)                                                                        False
# ...

# %%
reviews.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
reviews.loc [ reviews[ 'points'] ==100,   ] #  세로로 points값 구해서 헷갈리는거, 가로를 비교해야한다 생각, 세로는 다옴
# Out:
#           country                                        description  \
# 345     Australia  This wine contains some material over 100 year...
# 7335        Italy  Thick as molasses and dark as caramelized brow...
# 36528      France  This is a fabulous wine from the greatest Cham...
# 39286       Italy  A perfect wine from a classic vintage, the 200...
# 42197    Portugal  This is the latest release of what has long be...
# 45781       Italy  This gorgeous, fragrant wine opens with classi...
# 45798          US  Tasted in a flight of great and famous Napa wi...
# 58352      France  This is a magnificently solid wine, initially ...
# 89728      France  This latest incarnation of the famous brand is...
# 89729      France  This new release from a great vintage for Char...
# 111753     France  Almost black in color, this stunning wine is g...
# 111754      Italy  It takes only a few moments before you appreci...
# 111755     France  This is the finest Cheval Blanc for many years...
# ...

# %%
reviews.loc [ reviews[ 'points'] ==100 , ].shape
# Out:
# (19, 13)

# %% [markdown]
# ## taster_name 컬럼은 사람 이름으로 되어있다. 몇명의 사람들이 평가를 한것인까?

# %%
reviews.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
#1

# %%
reviews['taster_name'].describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
reviews['taster_name'].describe().unique()
# Out:
# array([103727, 19, 'Roger Voss', 25514], dtype=object)

# %%
#2

# %%
reviews['taster_name'].nunique()
# Out:
# 19

# %%
#3

# %%
reviews['taster_name'].unique() # 나, 아래래, nan까지 나옴--nunique나 describe + unique 로 해야 nan포함안됨
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
len( reviews['taster_name'].unique() )
# Out:
# 20

# %% [markdown]
# 리뷰 포인트의 평균을 구하시오

# %%
reviews['points'].mean() # 나
# Out:
# 88.44713820775404

# %% [markdown]
# ## 테스터들의 이름을 전부 확인하시오

# %%
reviews['taster_name'].unique() # 나, 맞음
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %% [markdown]
# ## 각 테스터들은, 각각 몇개의 와인을 테스트 했는지 확인하시오. ( 테스터 이름, 갯수 )

# %%
reviews.head(2)
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
#
# ...

# %%
reviews['taster_name'].value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %% [markdown]
# ## 리뷰의 포인트의 평균을 구하고, 리뷰의 포인트값이, 평균보다 큰 데이터 (즉, 평가가 좋은 와인) 만 가져오시오.

# %%
reviews['points'].mean()
# Out:
# 88.44713820775404

# %%
reviews.loc[   reviews['points'] > reviews['points'].mean() , ] # 나
# Out:
#                                                       country  \
# title
# Dopff & Irion 2004 Schoenenbourg Grand Cru Vend...     France
# Ceretto 2003 Bricco Rocche Prapó  (Barolo)              Italy
# Matrix 2007 Stuhlmuller Vineyard Chardonnay (Al...         US
# Mauritson 2007 Rockpile Cemetary Vineyard Zinfa...         US
# Henry's Drive Vignerons 2006 Parson's Flat Shir...  Australia
# ...                                                       ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...    Germany
# Citation 2004 Pinot Noir (Oregon)                          US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)     France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...     France
#
#                                                                                           description  \
# title
# Dopff & Irion 2004 Schoenenbourg Grand Cru Vend...  Medium-gold in color. Complex and inviting nos...
# ...
